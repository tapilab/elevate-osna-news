# %%
import pandas as pd
directory='/Users/mike/Downloads/training_data/twitter.csv.gz'
data=pd.read_csv(directory)
#data=data[0:100]
#data.set_index('social_id').loc[1972425520]

# %%
s_id = data['social_id'][10]
s_id
# Out:
# 2554608773

# %%
import re 
data_match=pd.read_csv('/Users/mike/Downloads/training_data/factchecks.csv')
d = data_match[data_match['site'] == 'twitter']
d['social_id'] = d['social_id'].astype(int)
joined = d.merge(data,on = 'social_id',how = 'outer')
# Out:
# /Users/mike/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
joined
# Out:
#                  social_id   site_x checkedby ruling   ruling_time  \
# 0       920299932166316033  twitter    snopes  FALSE  1.508255e+09
# 1       920307162278236160  twitter    snopes  FALSE  1.508255e+09
# 2       920307162278236160  twitter    snopes  FALSE  1.508255e+09
# 3       920307162278236160  twitter    snopes  FALSE  1.508255e+09
# 4       920307162278236160  twitter    snopes  FALSE  1.508255e+09
# 5       920307162278236160  twitter    snopes  FALSE  1.508255e+09
# 6       920307162278236160  twitter    snopes  FALSE  1.508255e+09
# 7       920307162278236160  twitter    snopes  FALSE  1.508255e+09
# 8       920307162278236160  twitter    snopes  FALSE  1.508255e+09
# 9       920307162278236160  twitter    snopes  FALSE  1.508255e+09
# 10      920307162278236160  twitter    snopes  FALSE  1.508255e+09
# 11      920307162278236160  twitter    snopes  FALSE  1.508255e+09
# 12      920307162278236160  twitter    snopes  FALSE  1.508255e+09
# ...

# %%
def simple_tokenizer(s):
    return s.split()
data=pd.Series.to_string(data.comment_tokens)
# Out:
# '0    rt @senjohnmccain : obama ha more czar than th...\n1    rt @senjohnmccain : obama ha more czar than th...\n2    rt @senjohnmccain : obama ha more czar than th...\n3    rt @senjohnmccain : obama ha more czar than th...\n4    rt @senjohnmccain : obama ha more czar than th...\n5    rt @senjohnmccain : obama ha more czar than th...\n6    rt @senjohnmccain : obama ha more czar than th...\n7    rt @thatkevinsmith : ten year in and we bone l...\n8    rt @thatkevinsmith : ten year in and we bone l...\n9    rt @thatkevinsmith : ten year in and we bone l...'

# %%
from collections import Counter
def common_words(data):
    counts=Counter()
    for d in data:
        counts.update(d[])
    return counts
